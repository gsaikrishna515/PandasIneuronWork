# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df.tail(10)
# Out:
#      Package          Item                                 Title  Rows  Cols  \
# 1704     vcd        Saxony                    Families in Saxony    13     2
# 1705     vcd     SexualFun                            Sex is Fun    16     3
# 1706     vcd  SpaceShuttle         Space Shuttle O-ring Failures    24     6
# 1707     vcd       Suicide              Suicide Rates in Germany   306     6
# 1708     vcd        Trucks                  Truck Accidents Data    24     5
# 1709     vcd      UKSoccer                      UK Soccer Scores    25     3
# 1710     vcd  VisualAcuity  Visual Acuity in Left and Right Eyes    32     4
# 1711     vcd       VonBort      Von Bortkiewicz Horse Kicks Data   280     4
# 1712     vcd    WeldonDice                    Weldon's Dice Data    11     2
# 1713     vcd    WomenQueue                       Women in Queues    11     2
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1704         0            0         1          0          1
# 1705         0            0         2          0          1
# 1706         1            0         2          0          4
# 1707         1            0         4          0          2
# 1708         3            0         4          0          1
# 1709         0            0         2          0          1
# 1710         1            0         3          0          1
# 1711         1            0         2          0          2
# 1712         0            0         1          0          1
# 1713         0            0         1          0          1
#
#                                                     CSV  \
# 1704  https://vincentarelbundock.github.io/Rdatasets...
# 1705  https://vincentarelbundock.github.io/Rdatasets...
# 1706  https://vincentarelbundock.github.io/Rdatasets...
# 1707  https://vincentarelbundock.github.io/Rdatasets...
# 1708  https://vincentarelbundock.github.io/Rdatasets...
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc
# 1704  https://vincentarelbundock.github.io/Rdatasets...
# 1705  https://vincentarelbundock.github.io/Rdatasets...
# 1706  https://vincentarelbundock.github.io/Rdatasets...
# 1707  https://vincentarelbundock.github.io/Rdatasets...
# 1708  https://vincentarelbundock.github.io/Rdatasets...
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713  https://vincentarelbundock.github.io/Rdatasets...

# %%
df.iloc[:12]
# Out:
#    Package             Item  \
# 0      AER          Affairs
# 1      AER     ArgentinaCPI
# 2      AER        BankWages
# 3      AER    BenderlyZwick
# 4      AER        BondYield
# 5      AER  CartelStability
# 6      AER        CASchools
# 7      AER      ChinaIncome
# 8      AER      CigarettesB
# 9      AER     CigarettesSW
# 10     AER  CollegeDistance
# 11     AER     ConsumerGood
#
#                                                 Title  Rows  Cols  n_binary  \
# 0                    Fair's Extramarital Affairs Data   601     9         2
# 1                   Consumer Price Index in Argentina    80     2         0
# 2                                          Bank Wages   474     4         2
# 3   Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                     Bond Yield Data    60     2         0
# 5                                     CartelStability   328     5         2
# 6                          California Test Score Data   420    14         1
# 7                   Chinese Real National Income Data    37     5         0
# 8                          Cigarette Consumption Data    46     3         0
# 9                    Cigarette Consumption Panel Data    96     9         2
# 10                              College Distance Data  4739    14         7
# 11          Properties of a Fast-Moving Consumer Good   108     3         0
#
#     n_character  n_factor  n_logical  n_numeric  \
# 0             0         2          0          7
# 1             0         0          0          2
# 2             0         3          0          1
# 3             0         0          0          5
# 4             0         0          0          2
# 5             0         3          0          2
# 6             2         2          0         10
# 7             0         0          0          5
# 8             0         0          0          3
# 9             0         2          0          7
# 10            0         8          0          6
# 11            0         0          0          3
#
#                                                   CSV  \
# 0   https://vincentarelbundock.github.io/Rdatasets...
# 1   https://vincentarelbundock.github.io/Rdatasets...
# 2   https://vincentarelbundock.github.io/Rdatasets...
# 3   https://vincentarelbundock.github.io/Rdatasets...
# 4   https://vincentarelbundock.github.io/Rdatasets...
# 5   https://vincentarelbundock.github.io/Rdatasets...
# 6   https://vincentarelbundock.github.io/Rdatasets...
# 7   https://vincentarelbundock.github.io/Rdatasets...
# 8   https://vincentarelbundock.github.io/Rdatasets...
# 9   https://vincentarelbundock.github.io/Rdatasets...
# 10  https://vincentarelbundock.github.io/Rdatasets...
# 11  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                   Doc
# 0   https://vincentarelbundock.github.io/Rdatasets...
# 1   https://vincentarelbundock.github.io/Rdatasets...
# 2   https://vincentarelbundock.github.io/Rdatasets...
# 3   https://vincentarelbundock.github.io/Rdatasets...
# 4   https://vincentarelbundock.github.io/Rdatasets...
# 5   https://vincentarelbundock.github.io/Rdatasets...
# 6   https://vincentarelbundock.github.io/Rdatasets...
# 7   https://vincentarelbundock.github.io/Rdatasets...
# 8   https://vincentarelbundock.github.io/Rdatasets...
# 9   https://vincentarelbundock.github.io/Rdatasets...
# 10  https://vincentarelbundock.github.io/Rdatasets...
# 11  https://vincentarelbundock.github.io/Rdatasets...

# %%
df.columns
# Out:
# Index(['Package', 'Item', 'Title', 'Rows', 'Cols', 'n_binary', 'n_character',
#        'n_factor', 'n_logical', 'n_numeric', 'CSV', 'Doc'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# 1709                                   UK Soccer Scores    25     3         0
# 1710               Visual Acuity in Left and Right Eyes    32     4         1
# 1711                   Von Bortkiewicz Horse Kicks Data   280     4         1
# 1712                                 Weldon's Dice Data    11     2         0
# 1713                                    Women in Queues    11     2         0
#
#       n_character  n_factor  n_logical  n_numeric  \
# 0               0         2          0          7
# 1               0         0          0          2
# 2               0         3          0          1
# 3               0         0          0          5
# 4               0         0          0          2
# ...           ...       ...        ...        ...
# 1709            0         2          0          1
# 1710            0         3          0          1
# 1711            0         2          0          2
# 1712            0         1          0          1
# 1713            0         1          0          1
#
#                                                     CSV  \
# 0     https://vincentarelbundock.github.io/Rdatasets...
# 1     https://vincentarelbundock.github.io/Rdatasets...
# 2     https://vincentarelbundock.github.io/Rdatasets...
# 3     https://vincentarelbundock.github.io/Rdatasets...
# 4     https://vincentarelbundock.github.io/Rdatasets...
# ...                                                 ...
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc
# 0     https://vincentarelbundock.github.io/Rdatasets...
# 1     https://vincentarelbundock.github.io/Rdatasets...
# 2     https://vincentarelbundock.github.io/Rdatasets...
# 3     https://vincentarelbundock.github.io/Rdatasets...
# 4     https://vincentarelbundock.github.io/Rdatasets...
# ...                                                 ...
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713  https://vincentarelbundock.github.io/Rdatasets...
#
# [1714 rows x 12 columns]>

# %%
df.dtypes
# Out:
# Package        object
# Item           object
# Title          object
# Rows            int64
# Cols            int64
# n_binary        int64
# n_character     int64
# n_factor        int64
# n_logical       int64
# n_numeric       int64
# CSV            object
# Doc            object
# dtype: object

# %%
df[df.dtypes[df.dtypes=='int64'].index]
# Out:
#       Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric
# 0      601     9         2            0         2          0          7
# 1       80     2         0            0         0          0          2
# 2      474     4         2            0         3          0          1
# 3       31     5         0            0         0          0          5
# 4       60     2         0            0         0          0          2
# ...    ...   ...       ...          ...       ...        ...        ...
# 1709    25     3         0            0         2          0          1
# 1710    32     4         1            0         3          0          1
# 1711   280     4         1            0         2          0          2
# 1712    11     2         0            0         1          0          1
# 1713    11     2         0            0         1          0          1
#
# [1714 rows x 7 columns]

# %%
df['New_Data']=df['Cols']

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# 1709                                   UK Soccer Scores    25     3         0
# 1710               Visual Acuity in Left and Right Eyes    32     4         1
# 1711                   Von Bortkiewicz Horse Kicks Data   280     4         1
# 1712                                 Weldon's Dice Data    11     2         0
# 1713                                    Women in Queues    11     2         0
#
#       n_character  n_factor  n_logical  n_numeric  \
# 0               0         2          0          7
# 1               0         0          0          2
# 2               0         3          0          1
# 3               0         0          0          5
# 4               0         0          0          2
# ...           ...       ...        ...        ...
# 1709            0         2          0          1
# 1710            0         3          0          1
# 1711            0         2          0          2
# 1712            0         1          0          1
# 1713            0         1          0          1
#
#                                                     CSV  \
# 0     https://vincentarelbundock.github.io/Rdatasets...
# 1     https://vincentarelbundock.github.io/Rdatasets...
# 2     https://vincentarelbundock.github.io/Rdatasets...
# 3     https://vincentarelbundock.github.io/Rdatasets...
# 4     https://vincentarelbundock.github.io/Rdatasets...
# ...                                                 ...
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc  New_Data
# 0     https://vincentarelbundock.github.io/Rdatasets...         9
# 1     https://vincentarelbundock.github.io/Rdatasets...         2
# 2     https://vincentarelbundock.github.io/Rdatasets...         4
# 3     https://vincentarelbundock.github.io/Rdatasets...         5
# 4     https://vincentarelbundock.github.io/Rdatasets...         2
# ...                                                 ...       ...
# 1709  https://vincentarelbundock.github.io/Rdatasets...         3
# 1710  https://vincentarelbundock.github.io/Rdatasets...         4
# 1711  https://vincentarelbundock.github.io/Rdatasets...         4
# 1712  https://vincentarelbundock.github.io/Rdatasets...         2
# 1713  https://vincentarelbundock.github.io/Rdatasets...         2
#
# [1714 rows x 13 columns]

# %%
df.loc[5]
# Out:
# Package                                                      AER
# Item                                             CartelStability
# Title                                            CartelStability
# Rows                                                         328
# Cols                                                           5
# n_binary                                                       2
# n_character                                                    0
# n_factor                                                       3
# n_logical                                                      0
# n_numeric                                                      2
# CSV            https://vincentarelbundock.github.io/Rdatasets...
# Doc            https://vincentarelbundock.github.io/Rdatasets...
# New_Data                                                       5
# Name: 5, dtype: object

# %%
df.dtypes
# Out:
# Package        object
# Item           object
# Title          object
# Rows            int64
# Cols            int64
# n_binary        int64
# n_character     int64
# n_factor        int64
# n_logical       int64
# n_numeric       int64
# CSV            object
# Doc            object
# New_Data        int64
# dtype: object

# %%
df.groupby(['Item','CSV']).mean()
# Out:
#                                                                   Rows  Cols  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...     22     2
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...    430    11
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...     24     5
# Accident     https://vincentarelbundock.github.io/Rdatasets/...     40     5
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...     30     3
# ...                                                                ...   ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...     50     2
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...  13583    13
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...    100    13
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...     24     3
# yule         https://vincentarelbundock.github.io/Rdatasets/...     32     5
#
#                                                                  n_binary  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...         0
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...         5
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...         2
# Accident     https://vincentarelbundock.github.io/Rdatasets/...         1
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...         0
# ...                                                                   ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...         2
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...         2
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...         2
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...         0
# yule         https://vincentarelbundock.github.io/Rdatasets/...         0
#
#                                                                  n_character  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...            0
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...            0
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...            0
# Accident     https://vincentarelbundock.github.io/Rdatasets/...            0
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...            0
# ...                                                                      ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...            0
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...            8
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...            8
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...            1
# yule         https://vincentarelbundock.github.io/Rdatasets/...            1
#
#                                                                  n_factor  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...         0
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...         4
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...         3
# Accident     https://vincentarelbundock.github.io/Rdatasets/...         3
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...         0
# ...                                                                   ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...         2
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...         0
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...         0
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...         0
# yule         https://vincentarelbundock.github.io/Rdatasets/...         0
#
#                                                                  n_logical  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...          0
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...          0
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...          0
# Accident     https://vincentarelbundock.github.io/Rdatasets/...          0
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...          0
# ...                                                                    ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...          0
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...          0
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...          0
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...          0
# yule         https://vincentarelbundock.github.io/Rdatasets/...          0
#
#                                                                  n_numeric  \
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...          2
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...          7
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...          2
# Accident     https://vincentarelbundock.github.io/Rdatasets/...          2
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...          3
# ...                                                                    ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...          0
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...          5
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...          5
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...          2
# yule         https://vincentarelbundock.github.io/Rdatasets/...          4
#
#                                                                  New_Data
# Item         CSV
# ACF1         https://vincentarelbundock.github.io/Rdatasets/...         2
# AHCAvote2017 https://vincentarelbundock.github.io/Rdatasets/...        11
# AMSsurvey    https://vincentarelbundock.github.io/Rdatasets/...         5
# Accident     https://vincentarelbundock.github.io/Rdatasets/...         5
# AccordPrice  https://vincentarelbundock.github.io/Rdatasets/...         3
# ...                                                                   ...
# yawn         https://vincentarelbundock.github.io/Rdatasets/...         2
# yrbss        https://vincentarelbundock.github.io/Rdatasets/...        13
# yrbss_samp   https://vincentarelbundock.github.io/Rdatasets/...        13
# yugo_sales   https://vincentarelbundock.github.io/Rdatasets/...         3
# yule         https://vincentarelbundock.github.io/Rdatasets/...         5
#
# [1714 rows x 8 columns]

# %%
df[df['Rows']>50]
# Out:
#      Package             Item                              Title  Rows  Cols  \
# 0        AER          Affairs   Fair's Extramarital Affairs Data   601     9
# 1        AER     ArgentinaCPI  Consumer Price Index in Argentina    80     2
# 2        AER        BankWages                         Bank Wages   474     4
# 4        AER        BondYield                    Bond Yield Data    60     2
# 5        AER  CartelStability                    CartelStability   328     5
# ...      ...              ...                                ...   ...   ...
# 1691     vcd          Hitters                       Hitters Data   154     4
# 1702     vcd          RepVict          Repeat Victimization Data    64     3
# 1703     vcd         Rochdale                      Rochdale Data   256     9
# 1707     vcd          Suicide           Suicide Rates in Germany   306     6
# 1711     vcd          VonBort   Von Bortkiewicz Horse Kicks Data   280     4
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0            2            0         2          0          7
# 1            0            0         0          0          2
# 2            2            0         3          0          1
# 4            0            0         0          0          2
# 5            2            0         3          0          2
# ...        ...          ...       ...        ...        ...
# 1691         0            0         1          0          3
# 1702         0            0         2          0          1
# 1703         8            0         8          0          1
# 1707         1            0         4          0          2
# 1711         1            0         2          0          2
#
#                                                     CSV  \
# 0     https://vincentarelbundock.github.io/Rdatasets...
# 1     https://vincentarelbundock.github.io/Rdatasets...
# 2     https://vincentarelbundock.github.io/Rdatasets...
# 4     https://vincentarelbundock.github.io/Rdatasets...
# 5     https://vincentarelbundock.github.io/Rdatasets...
# ...                                                 ...
# 1691  https://vincentarelbundock.github.io/Rdatasets...
# 1702  https://vincentarelbundock.github.io/Rdatasets...
# 1703  https://vincentarelbundock.github.io/Rdatasets...
# 1707  https://vincentarelbundock.github.io/Rdatasets...
# 1711  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc  New_Data
# 0     https://vincentarelbundock.github.io/Rdatasets...         9
# 1     https://vincentarelbundock.github.io/Rdatasets...         2
# 2     https://vincentarelbundock.github.io/Rdatasets...         4
# 4     https://vincentarelbundock.github.io/Rdatasets...         2
# 5     https://vincentarelbundock.github.io/Rdatasets...         5
# ...                                                 ...       ...
# 1691  https://vincentarelbundock.github.io/Rdatasets...         4
# 1702  https://vincentarelbundock.github.io/Rdatasets...         3
# 1703  https://vincentarelbundock.github.io/Rdatasets...         9
# 1707  https://vincentarelbundock.github.io/Rdatasets...         6
# 1711  https://vincentarelbundock.github.io/Rdatasets...         4
#
# [1122 rows x 13 columns]

# %%
for i in range(len(df)):
    if i<=20:
        
        print(df['CSV'][i])
# Out:
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/ArgentinaCPI.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/BankWages.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/BenderlyZwick.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/BondYield.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CartelStability.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CASchools.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/ChinaIncome.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CigarettesB.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CigarettesSW.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CollegeDistance.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/ConsumerGood.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPS1985.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPS1988.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSW04.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSW3.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSW8.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSW9204.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSW9298.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CPSSWEducation.csv
# https://vincentarelbundock.github.io/Rdatasets/csv/AER/CreditCard.csv

# %%
df2=df[['CSV','Title','Rows']]

# %%
df2.to_csv('NewFile.csv')

# %%
df3=pd.read_csv('NewFile.csv')

# %%
df3
# Out:
#       Unnamed: 0                                                CSV  \
# 0              0  https://vincentarelbundock.github.io/Rdatasets...
# 1              1  https://vincentarelbundock.github.io/Rdatasets...
# 2              2  https://vincentarelbundock.github.io/Rdatasets...
# 3              3  https://vincentarelbundock.github.io/Rdatasets...
# 4              4  https://vincentarelbundock.github.io/Rdatasets...
# ...          ...                                                ...
# 1709        1709  https://vincentarelbundock.github.io/Rdatasets...
# 1710        1710  https://vincentarelbundock.github.io/Rdatasets...
# 1711        1711  https://vincentarelbundock.github.io/Rdatasets...
# 1712        1712  https://vincentarelbundock.github.io/Rdatasets...
# 1713        1713  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                   Title  Rows
# 0                      Fair's Extramarital Affairs Data   601
# 1                     Consumer Price Index in Argentina    80
# 2                                            Bank Wages   474
# 3     Benderly and Zwick Data: Inflation, Growth and...    31
# 4                                       Bond Yield Data    60
# ...                                                 ...   ...
# 1709                                   UK Soccer Scores    25
# 1710               Visual Acuity in Left and Right Eyes    32
# 1711                   Von Bortkiewicz Horse Kicks Data   280
# 1712                                 Weldon's Dice Data    11
# 1713                                    Women in Queues    11
#
# [1714 rows x 4 columns]

# %%
df4=df2+df

# %%
df4
# Out:
#                                                     CSV  Cols  Doc  Item  \
# 0     https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 1     https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 2     https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 3     https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 4     https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# ...                                                 ...   ...  ...   ...
# 1709  https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 1710  https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 1711  https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 1712  https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
# 1713  https://vincentarelbundock.github.io/Rdatasets...   NaN  NaN   NaN
#
#       New_Data  Package  Rows  \
# 0          NaN      NaN  1202
# 1          NaN      NaN   160
# 2          NaN      NaN   948
# 3          NaN      NaN    62
# 4          NaN      NaN   120
# ...        ...      ...   ...
# 1709       NaN      NaN    50
# 1710       NaN      NaN    64
# 1711       NaN      NaN   560
# 1712       NaN      NaN    22
# 1713       NaN      NaN    22
#
#                                                   Title  n_binary  \
# 0     Fair's Extramarital Affairs DataFair's Extrama...       NaN
# 1     Consumer Price Index in ArgentinaConsumer Pric...       NaN
# 2                                  Bank WagesBank Wages       NaN
# 3     Benderly and Zwick Data: Inflation, Growth and...       NaN
# 4                        Bond Yield DataBond Yield Data       NaN
# ...                                                 ...       ...
# 1709                   UK Soccer ScoresUK Soccer Scores       NaN
# 1710  Visual Acuity in Left and Right EyesVisual Acu...       NaN
# 1711  Von Bortkiewicz Horse Kicks DataVon Bortkiewic...       NaN
# 1712               Weldon's Dice DataWeldon's Dice Data       NaN
# 1713                     Women in QueuesWomen in Queues       NaN
#
#       n_character  n_factor  n_logical  n_numeric
# 0             NaN       NaN        NaN        NaN
# 1             NaN       NaN        NaN        NaN
# 2             NaN       NaN        NaN        NaN
# 3             NaN       NaN        NaN        NaN
# 4             NaN       NaN        NaN        NaN
# ...           ...       ...        ...        ...
# 1709          NaN       NaN        NaN        NaN
# 1710          NaN       NaN        NaN        NaN
# 1711          NaN       NaN        NaN        NaN
# 1712          NaN       NaN        NaN        NaN
# 1713          NaN       NaN        NaN        NaN
#
# [1714 rows x 13 columns]

# %%
df.isnull()
# Out:
#       Package   Item  Title   Rows   Cols  n_binary  n_character  n_factor  \
# 0       False  False  False  False  False     False        False     False
# 1       False  False  False  False  False     False        False     False
# 2       False  False  False  False  False     False        False     False
# 3       False  False  False  False  False     False        False     False
# 4       False  False  False  False  False     False        False     False
# ...       ...    ...    ...    ...    ...       ...          ...       ...
# 1709    False  False  False  False  False     False        False     False
# 1710    False  False  False  False  False     False        False     False
# 1711    False  False  False  False  False     False        False     False
# 1712    False  False  False  False  False     False        False     False
# 1713    False  False  False  False  False     False        False     False
#
#       n_logical  n_numeric    CSV    Doc  New_Data
# 0         False      False  False  False     False
# 1         False      False  False  False     False
# 2         False      False  False  False     False
# 3         False      False  False  False     False
# 4         False      False  False  False     False
# ...         ...        ...    ...    ...       ...
# 1709      False      False  False  False     False
# 1710      False      False  False  False     False
# 1711      False      False  False  False     False
# 1712      False      False  False  False     False
# 1713      False      False  False  False     False
#
# [1714 rows x 13 columns]
